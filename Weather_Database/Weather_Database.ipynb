# %%
# Import the dependencies 
import pandas as pd 
from citipy import citipy
import numpy as np 
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
print(cities)
# Out:
# ['parkersburg', 'pierre', 'mataura', 'longyearbyen', 'vaitupu', 'batticaloa', 'san carlos de bariloche', 'ketchikan', 'samusu', 'coquimbo', 'qaanaaq', 'asheville', 'charters towers', 'lock haven', 'cidreira', 'ancud', 'perth', 'ushuaia', 'grand river south east', 'hobyo', 'mpika', 'bankja', 'port alfred', 'kaitangata', 'albany', 'ribeira brava', 'saryshagan', 'chuy', 'dicabisagan', 'vardo', 'pandan', 'grindavik', 'maragogi', 'bubaque', 'coihaique', 'jamestown', 'belmonte', 'upernavik', 'lavrentiya', 'bredasdorp', 'puerto ayora', 'khatanga', 'hofn', 'dudinka', 'pinawa', 'mar del plata', 'tasiilaq', 'tumannyy', 'cape town', 'nikolskoye', 'kidal', 'lima', 'hithadhoo', 'geraldton', 'kununurra', 'ribeira grande', 'butaritari', 'soe', 'lorengau', 'mastic beach', 'rikitea', 'igarka', 'port elizabeth', 'barrow', 'namibe', 'ovalle', 'puerto cabezas', 'koungou', 'bobosevo', 'mitu', 'aklavik', 'alma', 'yerbogachen', 'lafia', 'punta arenas', 'avarua', 'jiddah', 'carnarvon', 'illoqqortoormiut', 'tiffin', 'troitskoye', 'araouane', 'mys shmidta', 'norman wells', 'coolum beach', 'langres', 'tiksi', 'bengkulu', 'kapaa', 'macaboboni', 'los llanos de aridane', 'qafsah', 'fomboni', 'manggar', 'kuche', 'nouadhibou', 'bluff', 'zatoka', 'karratha', 'provideniya', 'hermanus', 'chokurdakh', 'malinovskiy', 'moranbah', 'saint-philippe', 'sitka', 'vaini', 'bandarbeyla', 'bambanglipuro', 'lebu', 'kodiak', 'saint-augustin', 'bathsheba', 'dongsheng', 'east london', 'bambous virieux', 'luderitz', 'necochea', 'odienne', 'koslan', 'yellowknife', 'nelson bay', 'phan thiet', 'kabompo', 'mantua', 'lufilufi', 'hilo', 'new norfolk', 'westport', 'suchitlan', 'dujuma', 'dangriga', 'cabo san lucas', 'saskylakh', 'laguna', 'puerto escondido', 'taolanaro', 'tuktoyaktuk', 'tabou', 'aranos', 'chara', 'yankton', 'pangnirtung', 'bosaso', 'klaksvik', 'tsihombe', 'yatou', 'ponta do sol', 'kipini', 'georgetown', 'broome', 'esperance', 'ilulissat', 'busselton', 'hervey bay', 'avera', 'yining', 'abha', 'ornskoldsvik', 'vilhena', 'khandyga', 'kodinsk', 'clyde river', 'srikakulam', 'akyab', 'havre-saint-pierre', 'auki', 'raudeberg', 'marawi', 'nioro', 'trairi', 'youkounkoun', 'beringovskiy', 'dundee', 'zhigansk', 'airai', 'langxiang', 'kavaratti', 'komsomolskiy', 'cayenne', 'westpunt', 'ahipara', 'barentsburg', 'meulaboh', 'shar', 'nizhneyansk', 'duma', 'camacha', 'mezhdurechensk', 'srandakan', 'castro', 'uvelskiy', 'guerrero negro', 'snyder', 'ayan', 'mount gambier', 'malmesbury', 'vostok', 'atuona', 'torbay', 'port lincoln', 'przeworsk', 'presque isle', 'troitsko-pechorsk', 'adilabad', 'tornio', 'paamiut', 'porteirinha', 'vila franca do campo', 'port augusta', 'college', 'hobart', 'sur', 'asbestos', 'port hardy', 'samarai', 'bogorodskoye', 'mentougou', 'ayagoz', 'opuwo', 'sydney', 'kuala terengganu', 'petropavlovsk-kamchatskiy', 'roebourne', 'kavieng', 'thompson', 'broken hill', 'mpulungu', 'arraial do cabo', 'ust-tsilma', 'bantou', 'florianopolis', 'alugan', 'victoria', 'fukue', 'okha', 'geresk', 'sangar', 'linkoping', 'talnakh', 'koumac', 'shimoda', 'hami', 'lagoa', 'faya', 'luanda', 'tual', 'ibra', 'dikson', 'tranas', 'russell', 'zmeinogorsk', 'tura', 'oga', 'husavik', 'severo-kurilsk', 'mazara del vallo', 'grand gaube', 'cairns', 'portel', 'iskateley', 'sokode', 'morong', 'buala', 'san rafael', 'byron bay', 'khonuu', 'louisbourg', 'rocha', 'omboue', 'jiangyou', 'kahului', 'buqayq', 'severodvinsk', 'mabaruma', 'vestmannaeyjar', 'ivdel', 'caucaia', 'prince rupert', 'balakliya', 'naze', 'pitimbu', 'urdoma', 'weligama', 'faanui', 'mahebourg', 'bethel', 'dunedin', 'belushya guba', 'tuatapere', 'korla', 'meyungs', 'hirara', 'rincon', 'tarko-sale', 'korablino', 'shu', 'krasnoselkup', 'touros', 'sentyabrskiy', 'taoudenni', 'jalu', 'tucuman', 'vredendal', 'jega', 'kortkeros', 'parker', 'ust-omchug', 'pisco', 'alihe', 'beyneu', 'alofi', 'saurimo', 'albacete', 'lubu', 'iqaluit', 'saleaula', 'bay roberts', 'kieta', 'mende', 'codrington', 'braganca', 'kapiri mposhi', 'porbandar', 'kinder ...

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997fc1b4931550cf118d5540ded7db84

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i,city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city. 
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | parkersburg
# Processing Record 2 of Set 1 | pierre
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 1 | batticaloa
# Processing Record 7 of Set 1 | san carlos de bariloche
# Processing Record 8 of Set 1 | ketchikan
# Processing Record 9 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 1 | coquimbo
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | asheville
# Processing Record 13 of Set 1 | charters towers
# Processing Record 14 of Set 1 | lock haven
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | ancud
# Processing Record 17 of Set 1 | perth
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 1 | hobyo
# Processing Record 21 of Set 1 | mpika
# Processing Record 22 of Set 1 | bankja
# City not found. Skipping...
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | kaitangata
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | ribeira brava
# Processing Record 27 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | dicabisagan
# Processing Record 30 of Set 1 | vardo
# Processing Record 31 of Set 1 | pandan
# Processing Record 32 of Set 1 | grindavik
# Processing Record 33 of Set 1 | maragogi
# Processing Record 34 of Set 1 | bubaque
# Processing Record 35 of Set 1 | coihaique
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | belmonte
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | lavrentiya
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | hofn
# Processing Record 44 of Set 1 | dudinka
# Processing Record 45 of Set 1 | pinawa
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | kidal
# Processing Record 2 of Set 2 | lima
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | geraldton
# Processing Record 5 of Set 2 | kununurra
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | soe
# Processing Record 9 of Set 2 | lorengau
# Processing Record 10 of Set 2 | mastic beach
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | igarka
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | ovalle
# Processing Record 17 of Set 2 | puerto cabezas
# Processing Record 18 of Set 2 | koungou
# Processing Record 19 of Set 2 | bobosevo
# City not found. Skipping...
# Processing Record 20 of Set 2 | mitu
# Processing Record 21 of Set 2 | aklavik
# Processing Record 22 of Set 2 | alma
# Processing Record 23 of Set 2 | yerbogachen
# Processing Record 24 of Set 2 | lafia
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | tiffin
# Processing Record 31 of Set 2 | troitskoye
# Processing Record 32 of Set 2 | araouane
# Processing Record 33 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 2 | norman wells
# Processing Record 35 of Set 2 | coolum beach
# Processing Record 36 of Set 2 | langres
# Processing Record 37 of Set 2 | tiksi
# Processing Record 38 of Set 2 | bengkulu
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 41 of Set 2 | los llanos de aridane
# Processing Record 42 of Set 2 | qafsah
# City not found. Skipping...
# Processing Record 43 of Set 2 | fomboni
# Processing Record 44 of Set 2 | manggar
# Processing Record 45 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 2 | nouadhibou
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | zatoka
# Processing Record 49 of Set 2 | karratha
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | malinovskiy
# Processing Record 4 of Set 3 | moranbah
# Processing Record 5 of Set 3 | saint-philippe
# Processing Record 6 of Set 3 | sitka
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | bandarbeyla
# Processing Record 9 of Set 3 | bambanglipuro
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | kodiak
# Processing Record 12 of Set 3 | saint-augustin
# Processing Record 13 of Set 3 | bathsheba
# Processing Record 14 of Set 3 | dongsheng
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | necochea
# Processing Record 19 of Set 3 | odienne
# Processing Record 20 of Set 3 | koslan
# Processing Record 21 of Set 3 | yellowknife
# Processing Record 22 of Set 3 | nelson bay
# Processing Record 23 of Set 3 | phan thiet
# Processing Record 24 of Set 3 | kabompo
# Processing Record 25 of Set 3 | mantua
# Processing Record 26 of Set 3 | lufilufi
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | new norfolk
# Processing Record 29 of Set 3 | westport
# Processing Record 30 of Set 3 | suchitlan
# Processing Record 31 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 32 of Set 3 | dangriga
# Processing Record 33 of Set 3 | cabo san lucas
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | laguna
# Processing Record 36 of Set 3 | puerto escondido
# Processing Record 37 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | tabou
# Processing Record 40 of Set 3 | aranos
# Processing Record 41 of Set 3 | chara
# Processing Record 42 of Set 3 | yankton
# Processing Record 43 of Set 3 | pangnirtung
# Processing Record 44 of Set 3 | bosaso
# Processing Record 45 of Set 3 | klaksvik
# Processing Record 46 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 3 | yatou
# Processing Record 48 of Set 3 | ponta do sol
# Processing Record 49 of Set 3 | kipini
# Processing Record 50 of Set 3 | georgetown
# Processing Record 1 of Set 4 | broome
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | ilulissat
# Processing Record 4 of Set 4 | busselton
# Processing Record 5 of Set 4 | hervey bay
# Processing Record 6 of Set 4 | avera
# Processing Record 7 of Set 4 | yining
# Processing Record 8 of Set 4 | abha
# Processing Record 9 of Set 4 | ornskoldsvik
# Processing Record 10 of Set 4 | vilhena
# Processing Record 11 of Set 4 | khandyga
# Processing Record 12 of Set 4 | kodinsk
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | srikakulam
# Processing Record 15 of Set 4 | akyab
# Processing Record 16 of Set 4 | havre-saint-pierre
# Processing Record 17 of Set 4 | auki
# Processing Record 18 of Set 4 | raudeberg
# Processing Record 19 of Set 4 | marawi
# Processing Record 20 of Set 4 | nioro
# Processing Record 21 of Set 4 | trairi
# Processing Record 22 of Set 4 | youkounkoun
# Processing Record 23 of Set 4 | beringovskiy
# Processing Record 24 of Set 4 | dundee
# Processing Record 25 of Set 4 | zhigansk
# Processing Record 26 of Set 4 | airai
# Processing Record 27 of Set 4 | langxiang
# Processing Record 28 of Set 4 | kavaratti
# Processing Record 29 of Set 4 | komsomolskiy
# Processing Record 30 of Set 4 | cayenne
# Processing Record 31 of Set 4 | westpunt
# City not found. Skipping...
# Processing Record 32 of Set 4 | ahipara
# Processing Record 33 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 4 | meulaboh
# Processing Record 35 of Set 4 | shar
# Processing Record 36 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 4 | duma
# Processing Record 38 of Set 4 | camacha
# Processing Record 39 of Set 4 | mezhdurechensk
# Processing Record 40 of Set 4 | srandakan
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | uvelskiy
# Processing Record 43 of Set 4 | guerrero negro
# Processing Record 44 of Set 4 | snyder
# Processing Record 45 of Set 4 | ayan
# Processing Record 46 of Set 4 | mount gambier
# Processing Record 47 of Set 4 | malmesbury
# Processing Record 48 of Set 4 | vostok
# Processing Record 49 of Set 4 | atuona
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | port lincoln
# Processing Record 2 of Set 5 | przeworsk
# Processing Record 3 of Set 5 | presque isle
# Processing Record 4 of Set 5 | troitsko-pechorsk
# Processing Record 5 of Set 5 | adilabad
# Processing Record 6 of Set 5 | tornio
# Processing Record 7 of Set 5 | paamiut
# Processing Record 8 of Set 5 | porteirinha
# Processing Record 9 of Set 5 | vila franca do campo
# Processing Record 10 of Set 5 | port augusta
# Processing Record 11 of Set 5 | college
# Processing Record 12 of Set 5 | hobart
# Processing Record 13 of Set 5 | sur
# Processing Record 14 of Set 5 | asbestos
# Processing Record 15 of Set 5 | port hardy
# Processing Record 16 of Set 5 | samarai
# Processing Record 17 of Set 5 | bogorodskoye
# Processing Record 18 of Set 5 | mentougou
# Processing Record 19 of Set 5 | ayagoz
# Processing Record 20 of Set 5 | opuwo
# Processing Record 21 of Set 5 | sydney
# Processing Record 22 of Set 5 | kuala terengganu
# Processing Record 23 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 5 | roebourne
# Processing Record 25 of Set 5 | kavieng
# Processing Record 26 of Set 5 | thompson
# Processing Record 27 of Set 5 | broken hill
# Processing Record 28 of Set 5 | mpulungu
# Processing Record 29 of Set 5 | arraial do cabo
# Processing Record 30 of Set 5 | ust-tsilma
# Processing Record 31 of Set 5 | bantou
# Processing Record 32 of Set 5 | florianopolis
# Processing Record 33 of Set 5 | alugan
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | fukue
# Processing Record 36 of Set 5 | okha
# Processing Record 37 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 38 of Set 5 | sangar
# Processing Record 39 of Set 5 | linkoping
# Processing Record 40 of Set 5 | talnakh
# Processing Record 41 of Set 5 | koumac
# Processing Record 42 of Set 5 | shimoda
# Processing Record 43 of Set 5 | hami
# Processing Record 44 of Set 5 | lagoa
# Processing Record 45 of Set 5 | faya
# Processing Record 46 of Set 5 | luanda
# Processing Record 47 of Set 5 | tual
# Processing Record 48 of Set 5 | ibra
# Processing Record 49 of Set 5 | dikson
# Processing Record 50 of Set 5 | tranas
# Processing Record 1 of Set 6 | russell
# Processing Record 2 of Set 6 | zmeinogorsk
# Processing Record 3 of Set 6 | tura
# Processing Record 4 of Set 6 | oga
# Processing Record 5 of Set 6 | husavik
# Processing Record 6 of Set 6 | severo-kurilsk
# Processing Record 7 of Set 6 | mazara del vallo
# Processing Record 8 of Set 6 | grand gaube
# Processing Record 9 of Set 6 | cairns
# Processing Record 10 of Set 6 | portel
# Processing Record 11 of Set 6 | iskateley
# Processing Record 12 of Set 6 | sokode
# Processing Record 13 of Set 6 | morong
# Processing Record 14 of Set 6 | buala
# Processing Record 15 of Set 6 | san rafael
# Processing Record 16 of Set 6 | byron bay
# Processing Record 17 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 6 | rocha
# Processing Record 20 of Set 6 | omboue
# Processing Record 21 of Set 6 | jiangyou
# Processing Record 22 of Set 6 | kahului
# Processing Record 23 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 6 | severodvinsk
# Processing Record 25 of Set 6 | mabaruma
# Processing Record 26 of Set 6 | vestmannaeyjar
# Processing Record 27 of Set 6 | ivdel
# Processing Record 28 of Set 6 | caucaia
# Processing Record 29 of Set 6 | prince rupert
# Processing Record 30 of Set 6 | balakliya
# Processing Record 31 of Set 6 | naze
# Processing Record 32 of Set 6 | pitimbu
# Processing Record 33 of Set 6 | urdoma
# Processing Record 34 of Set 6 | weligama
# Processing Record 35 of Set 6 | faanui
# Processing Record 36 of Set 6 | mahebourg
# Processing Record 37 of Set 6 | bethel
# Processing Record 38 of Set 6 | dunedin
# Processing Record 39 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 6 | tuatapere
# Processing Record 41 of Set 6 | korla
# Processing Record 42 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 6 | hirara
# Processing Record 44 of Set 6 | rincon
# Processing Record 45 of Set 6 | tarko-sale
# Processing Record 46 of Set 6 | korablino
# Processing Record 47 of Set 6 | shu
# Processing Record 48 of Set 6 | krasnoselkup
# Processing Record 49 of Set 6 | touros
# Processing Record 50 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 7 | taoudenni
# Processing Record 2 of Set 7 | jalu
# Processing Record 3 of Set 7 | tucuman
# Processing Record 4 of Set 7 | vredendal
# Processing Record 5 of Set 7 | jega
# Processing Record 6 of Set 7 | kortkeros
# Processing Record 7 of Set 7 | parker
# Processing Record 8 of Set 7 | ust-omchug
# Processing Record 9 of Set 7 | pisco
# Processing Record 10 of Set 7 | alihe
# Processing Record 11 of Set 7 | beyneu
# Processing Record 12 of Set 7 | alofi
# Processing Record 13 of Set 7 | saurimo
# Processing Record 14 of Set 7 | albacete
# Processing Record 15 of Set 7 | lubu
# Processing Record 16 of Set 7 | iqaluit
# Processing Record 17 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 7 | bay roberts
# Processing Record 19 of Set 7 | kieta
# Processing Record 20 of Set 7 | mende
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | braganca
# Processing Record 23 of Set 7 | kapiri mposhi
# Processing Record 24 of Set 7 | porbandar
# Processing Record 25 of Set 7 | kindersley
# Processing Record 26 of Set 7 | comodoro rivadavia
# Processing Record 27 of Set 7 | flinders
# Processing Record 28 of Set 7 | san cristobal
# Processing Record 29 of Set 7 | gunnedah
# Processing Record 30 of Set 7 | rahuri
# Processing Record 31 of Set 7 | manaure
# Processing Record 32 of Set 7 | kropotkin
# Processing Record 33 of Set 7 | otjiwarongo
# Processing Record 34 of Set 7 | goundi
# Processing Record 35 of Set 7 | poya
# Processing Record 36 of Set 7 | sola
# Processing Record 37 of Set 7 | umm kaddadah
# Processing Record 38 of Set 7 | ouargaye
# Processing Record 39 of Set 7 | northfield
# Processing Record 40 of Set 7 | adrar
# Processing Record 41 of Set 7 | kirakira
# Processing Record 42 of Set 7 | fort nelson
# Processing Record 43 of Set 7 | coahuayana
# Processing Record 44 of Set 7 | gawler
# Processing Record 45 of Set 7 | salinas
# Processing Record 46 of Set 7 | manjacaze
# Processing Record 47 of Set 7 | owando
# Processing Record 48 of Set 7 | rehoboth
# Processing Record 49 of Set 7 | jamkhandi
# Processing Record 50 of Set 7 | hlobyne
# Processing Record 1 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 2 of Set 8 | sheridan
# Processing Record 3 of Set 8 | totness
# Processing Record 4 of Set 8 | griffin
# Processing Record 5 of Set 8 | souillac
# Processing Record 6 of Set 8 | san quintin
# Processing Record 7 of Set 8 | shaoguan
# Processing Record 8 of Set 8 | moron
# Processing Record 9 of Set 8 | the valley
# Processing Record 10 of Set 8 | gerede
# Processing Record 11 of Set 8 | hermiston
# Processing Record 12 of Set 8 | beloha
# Processing Record 13 of Set 8 | yar-sale
# Processing Record 14 of Set 8 | sao joao da barra
# Processing Record 15 of Set 8 | cherskiy
# Processing Record 16 of Set 8 | pacific grove
# Processing Record 17 of Set 8 | reconquista
# Processing Record 18 of Set 8 | tulun
# Processing Record 19 of Set 8 | palana
# Processing Record 20 of Set 8 | krishnarajasagara
# Processing Record 21 of Set 8 | phuket
# Processing Record 22 of Set 8 | banda aceh
# Processing Record 23 of Set 8 | tanushimaru
# Processing Record 24 of Set 8 | hamilton
# Processing Record 25 of Set 8 | poum
# Processing Record 26 of Set 8 | havoysund
# Processing Record 27 of Set 8 | kemijarvi
# Processing Record 28 of Set 8 | lunenburg
# Processing Record 29 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 8 | rio grande
# Processing Record 31 of Set 8 | katsuura
# Processing Record 32 of Set 8 | baft
# Processing Record 33 of Set 8 | pallasovka
# Processing Record 34 of Set 8 | narsaq
# Processing Record 35 of Set 8 | ormara
# Processing Record 36 of Set 8 | nanortalik
# Processing Record 37 of Set 8 | uvira
# Processing Record 38 of Set 8 | changping
# Processing Record 39 of Set 8 | muroto
# Processing Record 40 of Set 8 | wolgast
# Processing Record 41 of Set 8 | aktash
# Processing Record 42 of Set 8 | conceicao do araguaia
# Processing Record 43 of Set 8 | kirkuk
# Processing Record 44 of Set 8 | sosnovo-ozerskoye
# Processing Record 45 of Set 8 | port blair
# Processing Record 46 of Set 8 | bull savanna
# Processing Record 47 of Set 8 | saint george
# Processing Record 48 of Set 8 | azle
# Processing Record 49 of Set 8 | atar
# Processing Record 50 of Set 8 | key largo
# Processing Record 1 of Set 9 | hualmay
# Processing Record 2 of Set 9 | fort saint james
# Processing Record 3 of Set 9 | fortuna
# Processing Record 4 of Set 9 | mungaa
# Processing Record 5 of Set 9 | honningsvag
# Processing Record 6 of Set 9 | caravelas
# Processing Record 7 of Set 9 | sao filipe
# Processing Record 8 of Set 9 | miles city
# Processing Record 9 of Set 9 | requena
# Processing Record 10 of Set 9 | olafsvik
# Processing Record 11 of Set 9 | paita
# Processing Record 12 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 9 | talcahuano
# Processing Record 14 of Set 9 | nantucket
# Processing Record 15 of Set 9 | kijang
# Processing Record 16 of Set 9 | asau
# Processing Record 17 of Set 9 | lashio
# Processing Record 18 of Set 9 | jaisinghnagar
# Processing Record 19 of Set 9 | preobrazheniye
# Processing Record 20 of Set 9 | eyl
# Processing Record 21 of Set 9 | ryotsu
# Processing Record 22 of Set 9 | mimoso do sul
# Processing Record 23 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 9 | provost
# Processing Record 25 of Set 9 | visby
# Processing Record 26 of Set 9 | yuryevets
# Processing Record 27 of Set 9 | srednekolymsk
# Processing Record 28 of Set 9 | nyrob
# Processing Record 29 of Set 9 | ketrzyn
# Processing Record 30 of Set 9 | kanniyakumari
# Processing Record 31 of Set 9 | magaria
# Processing Record 32 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 9 | casablanca
# Processing Record 34 of Set 9 | strzegom
# Processing Record 35 of Set 9 | port macquarie
# Processing Record 36 of Set 9 | buta
# Processing Record 37 of Set 9 | san ignacio
# Processing Record 38 of Set 9 | morshansk
# Processing Record 39 of Set 9 | erdenet
# Processing Record 40 of Set 9 | buin
# Processing Record 41 of Set 9 | plettenberg bay
# Processing Record 42 of Set 9 | kruisfontein
# Processing Record 43 of Set 9 | san vicente
# Processing Record 44 of Set 9 | hudson bay
# Processing Record 45 of Set 9 | mayo
# Processing Record 46 of Set 9 | straja
# Processing Record 47 of Set 9 | chiang rai
# Processing Record 48 of Set 9 | calabozo
# Processing Record 49 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 9 | maceio
# Processing Record 1 of Set 10 | filadelfia
# Processing Record 2 of Set 10 | katangli
# Processing Record 3 of Set 10 | sorland
# Processing Record 4 of Set 10 | kaka
# Processing Record 5 of Set 10 | koson
# Processing Record 6 of Set 10 | guilin
# Processing Record 7 of Set 10 | verkhozim
# Processing Record 8 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 10 | rey bouba
# Processing Record 10 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 10 | tazovskiy
# Processing Record 12 of Set 10 | sept-iles
# Processing Record 13 of Set 10 | corning
# Processing Record 14 of Set 10 | aleksin
# Processing Record 15 of Set 10 | antropovo
# Processing Record 16 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 17 of Set 10 | kefamenanu
# Processing Record 18 of Set 10 | boende
# Processing Record 19 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 10 | cockburn town
# Processing Record 21 of Set 10 | svetlyy
# Processing Record 22 of Set 10 | hambantota
# Processing Record 23 of Set 10 | saint-pierre
# Processing Record 24 of Set 10 | porto velho
# Processing Record 25 of Set 10 | inhambane
# Processing Record 26 of Set 10 | basco
# Processing Record 27 of Set 10 | rio verde de mato grosso
# Processing Record 28 of Set 10 | kashi
# Processing Record 29 of Set 10 | lemon tree passage
# Processing Record 30 of Set 10 | ponta delgada
# Processing Record 31 of Set 10 | bone
# Processing Record 32 of Set 10 | anadyr
# Processing Record 33 of Set 10 | nizwa
# Processing Record 34 of Set 10 | santa maria
# Processing Record 35 of Set 10 | saldanha
# Processing Record 36 of Set 10 | wanning
# Processing Record 37 of Set 10 | harindanga
# Processing Record 38 of Set 10 | mazatlan
# Processing Record 39 of Set 10 | morant bay
# Processing Record 40 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 10 | navahrudak
# Processing Record 42 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 43 of Set 10 | el bordo
# Processing Record 44 of Set 10 | ubrique
# Processing Record 45 of Set 10 | buraydah
# Processing Record 46 of Set 10 | balabac
# Processing Record 47 of Set 10 | talara
# Processing Record 48 of Set 10 | valdivia
# Processing Record 49 of Set 10 | vesyegonsk
# Processing Record 50 of Set 10 | navalmoral de la mata
# Processing Record 1 of Set 11 | namtsy
# Processing Record 2 of Set 11 | simi
# Processing Record 3 of Set 11 | luba
# Processing Record 4 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 11 | ixtapa
# Processing Record 6 of Set 11 | berdigestyakh
# Processing Record 7 of Set 11 | mehamn
# Processing Record 8 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 11 | sao gabriel da cachoeira
# Processing Record 10 of Set 11 | juneau
# Processing Record 11 of Set 11 | svetlaya
# Processing Record 12 of Set 11 | riyadh
# Processing Record 13 of Set 11 | sorong
# Processing Record 14 of Set 11 | lahat
# Processing Record 15 of Set 11 | pak phanang
# Processing Record 16 of Set 11 | praia
# Processing Record 17 of Set 11 | ostrovnoy
# Processing Record 18 of Set 11 | pangai
# Processing Record 19 of Set 11 | tir pol
# City not found. Skipping...
# Processing Record 20 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 11 | te anau
# Processing Record 22 of Set 11 | aksu
# Processing Record 23 of Set 11 | lucea
# Processing Record 24 of Set 11 | ardakan
# Processing Record 25 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 11 | chapleau
# Processing Record 27 of Set 11 | acarau
# Processing Record 28 of Set 11 | balkanabat
# Processing Record 29 of Set 11 | trincomalee
# Processing Record 30 of Set 11 | oranjemund
# Processing Record 31 of Set 11 | cururupu
# Processing Record 32 of Set 11 | piacabucu
# Processing Record 33 of Set 11 | biltine
# Processing Record 34 of Set 11 | vila do maio
# Processing Record 35 of Set 11 | burica
# City not found. Skipping...
# Processing Record 36 of Set 11 | jacareacanga
# Processing Record 37 of Set 11 | kulhudhuffushi
# Processing Record 38 of Set 11 | hovd
# Processing Record 39 of Set 11 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 40 of Set 11 | viedma
# Processing Record 41 of Set 11 | baherden
# Processing Record 42 of Set 11 | kayerkan
# Processing Record 43 of Set 11 | naifaru
# Processing Record 44 of Set 11 | khani
# Processing Record 45 of Set 11 | kathu
# Processing Record 46 of Set 11 | nukus
# Processing Record 47 of Set 11 | dingle
# Processing Record 48 of Set 11 | hasaki
# Processing Record 49 of Set 11 | fecamp
# Processing Record 50 of Set 11 | dalbandin
# Processing Record 1 of Set 12 | hay river
# Processing Record 2 of Set 12 | bairiki
# Processing Record 3 of Set 12 | bac lieu
# Processing Record 4 of Set 12 | mandalgovi
# Processing Record 5 of Set 12 | takoradi
# Processing Record 6 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 7 of Set 12 | buchanan
# Processing Record 8 of Set 12 | goderich
# Processing Record 9 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 12 | kouango
# Processing Record 11 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 12 | nefteyugansk
# Processing Record 13 of Set 12 | axim
# Processing Record 14 of Set 12 | jamsa
# Processing Record 15 of Set 12 | hit
# Processing Record 16 of Set 12 | lompoc
# Processing Record 17 of Set 12 | oranjestad
# Processing Record 18 of Set 12 | presidencia roque saenz pena
# Processing Record 19 of Set 12 | lesnoy
# Processing Record 20 of Set 12 | ucluelet
# Processing Record 21 of Set 12 | leningradskiy
# Processing Record 22 of Set 12 | marzuq
# Processing Record 23 of Set 12 | genhe
# Processing Record 24 of Set 12 | gayeri
# Processing Record 25 of Set 12 | yuza
# Processing Record 26 of Set 12 | agadir
# Processing Record 27 of Set 12 | radcliff
# Processing Record 28 of Set 12 | arawa
# Processing Record 29 of Set 12 | berlevag
# Processing Record 30 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 12 | pasaje
# Processing Record 32 of Set 12 | pasighat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Parkersburg  39.2667  -81.5615     96.17        34           9
# 1                   Pierre  44.3683 -100.3510     98.06        42          79
# 2                  Mataura -46.1927  168.8643     31.48        89         100
# 3             Longyearbyen  78.2186   15.6401     48.04        93          75
# 4               Batticaloa   7.7102   81.6924     80.62        73         100
# 5  San Carlos De Bariloche -41.1456  -71.3082     43.25        68          72
# 6                Ketchikan  55.3422 -131.6461     58.77        88         100
# 7                 Coquimbo -29.9533  -71.3436     58.69        80          45
# 8                  Qaanaaq  77.4840  -69.3632     37.78        98         100
# 9                Asheville  35.6009  -82.5540     94.17        41           2
#
#    Wind Speed Country                 Date
# 0        7.94      US  2022-07-23 19:59:12
# 1       10.00      US  2022-07-23 19:58:42
# 2        2.15      NZ  2022-07-23 20:01:11
# 3        9.22      SJ  2022-07-23 20:01:11
# 4        7.09      LK  2022-07-23 20:01:11
# 5        8.77      AR  2022-07-23 20:01:12
# 6        4.52      US  2022-07-23 19:58:22
# 7        2.86      CL  2022-07-23 20:01:12
# 8        2.95      GL  2022-07-23 20:01:13
# 9        1.01      US  2022-07-23 19:59:37

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_data into a csv 
city_data_df.to_csv(output_data_file, index_label = "City_ID")
